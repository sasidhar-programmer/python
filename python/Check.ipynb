# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set()

# %%
plt.figure(figsize=(15,8)) 
a = np.array([np.sin(i) for i in range(1, 51)]) 
b = np.array([np.cos(i) for i in range(1, 51)]) 
plt.plot(a,b)
